# %%
# !pip install -qq convokit
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.2/183.2 kB 3.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 12.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 21.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.1/677.1 kB 20.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 32.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 20.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 6.6 MB/s eta 0:00:00
#   Building wheel for convokit (pyproject.toml) ... done
#   Building wheel for emoji (setup.py) ... done

# %%
# !pip install -qq scikit-surprise
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 9.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for scikit-surprise (setup.py) ... done

# %%
import pandas as pd
import numpy as np
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split
from surprise import accuracy
import convokit

# %%
# Load the Cornell Movie Dialogs Corpus
corpus = convokit.Corpus(filename=convokit.download("movie-corpus"))
# Out:
# Downloading movie-corpus to /root/.convokit/downloads/movie-corpus
# Downloading movie-corpus from http://zissou.infosci.cornell.edu/convokit/datasets/movie-corpus/movie-corpus.zip (40.9MB)... Done
# No configuration file found at /root/.convokit/config.yml; writing with contents:
# # Default Backend Parameters
# db_host: localhost:27017
# data_directory: ~/.convokit/saved-corpora
# default_backend: mem

# %%
# Display basic statistics
print("Number of conversations:", len(corpus.conversations))
print("Number of users:", len(corpus.speakers))
print("Number of utterances:", len(corpus.utterances))
# Out:
# Number of conversations: 83097
# Number of users: 9035
# Number of utterances: 304713

# %%
# Display information about conversations
for convo_id in corpus.get_conversation_ids():
    convo = corpus.get_conversation(convo_id)
    print("Conversation ID:", convo_id)
    print("Metadata:", convo.meta)
    print("Number of utterances in conversation:", len(convo.get_utterance_ids()))
    print()
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Conversation ID: L419720
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L419714
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L419711
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L419708
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L419696
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 12
#
# Conversation ID: L419694
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L419679
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L419675
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L419670
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L419664
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L419658
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L419654
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L419628
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L419611
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L419608
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L419606
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L419568
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L419564
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L419556
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L419551
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L419544
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L419539
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L419537
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L419487
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L419484
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L419478
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L419468
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 10
#
# Conversation ID: L419451
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 17
#
# Conversation ID: L419439
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L419411
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L419325
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L419312
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 12
#
# Conversation ID: L419303
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L419301
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L419299
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L419291
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L419288
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L419245
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 43
#
# Conversation ID: L419243
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L419234
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L419219
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 12
#
# Conversation ID: L419213
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L419209
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L419207
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L419197
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L419189
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L419178
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 11
#
# Conversation ID: L419162
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 16
#
# Conversation ID: L419868
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L419865
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L419814
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 24
#
# Conversation ID: L419648
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L419642
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L419637
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L419632
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L419618
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 10
#
# Conversation ID: L419348
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 15
#
# Conversation ID: L419343
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L419331
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L418972
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L418969
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L418964
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L418949
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L418941
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L418936
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L418918
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 17
#
# Conversation ID: L418916
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L419792
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 13
#
# Conversation ID: L419790
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L419782
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L419779
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L419774
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L419769
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L419755
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 14
#
# Conversation ID: L419753
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L419749
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L419650
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L419645
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L419640
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L419114
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L419108
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L420044
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 11
#
# Conversation ID: L420037
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L420026
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 11
#
# Conversation ID: L419435
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L419425
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L419415
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 9
#
# Conversation ID: L418967
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L418953
# Metadata: ConvoKitMeta({'movie_idx': 'm149', 'movie_name': 'ninotchka', 'release_year': '1939', 'rating': '7.90', 'votes': '6951', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 11
#
# Conversation ID: L421468
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L421458
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L421455
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L421420
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L421394
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420886
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L420879
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L421317
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L421315
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L421310
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L421302
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L421297
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L421255
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L421241
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L421218
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L421178
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L420173
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L421288
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L421281
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L421276
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L421270
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L421259
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 9
#
# Conversation ID: L421168
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420868
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420168
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L421249
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L421245
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L421237
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L421194
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L421175
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L421170
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L421113
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420877
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420874
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420842
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420837
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L420821
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420805
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L420271
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L420254
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L420231
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L420207
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420188
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420184
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L420175
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420170
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L420164
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L421526
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L421498
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L421494
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L421491
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L421484
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L421482
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L421472
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L421422
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L421417
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L421401
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L421387
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L420783
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L420152
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L420150
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420146
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L420141
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L420139
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420133
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L421325
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L421323
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L421239
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L421234
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L421231
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L421222
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L421216
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L421200
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L421197
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L421172
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L421165
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L421159
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L421148
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L421117
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L421111
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L421027
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L421025
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L421012
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420872
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420863
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L420860
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L420844
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420828
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L420744
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420740
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L420738
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420731
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L420729
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420726
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L420643
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420438
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L420342
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420328
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L420313
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420296
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L420283
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 13
#
# Conversation ID: L420279
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L420276
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420269
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420261
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L420252
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420228
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420194
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L420190
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420177
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L420159
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L420157
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420763
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L420761
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420389
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420384
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L420377
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L420373
# Metadata: ConvoKitMeta({'movie_idx': 'm150', 'movie_name': 'nixon', 'release_year': '1995', 'rating': '7.10', 'votes': '13878', 'genre': "['biography', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L420371
# ...
# Number of utterances in conversation: 6
#
# Conversation ID: L666019
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665957
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665904
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665896
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665891
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665873
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665868
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665865
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665861
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665840
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665802
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665798
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665775
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665755
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665748
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L665691
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665676
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665663
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665658
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665636
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665627
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L665623
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665615
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L665564
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665558
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665552
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665548
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666168
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666166
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666160
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666158
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666151
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L666149
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665949
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665900
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665885
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665694
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665651
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665994
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665992
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665987
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L666462
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666365
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L666361
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L666503
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666388
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 11
#
# Conversation ID: L666487
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666483
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666480
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666357
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666249
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666246
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666546
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666485
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666460
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666383
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666251
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666497
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L666575
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666324
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L666262
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666520
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666369
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L666256
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2

# %%
# Create empty lists to store data
conversation_ids = []
movie_indices = []
movie_names = []
release_years = []
ratings = []
votes = []
genres = []
num_utterances = []

# Loop through conversations and extract data
for convo_id in corpus.get_conversation_ids():
    convo = corpus.get_conversation(convo_id)

    # Extract metadata from ConvoKitMeta object
    metadata = convo.meta

    # Append data to respective lists
    conversation_ids.append(convo_id)
    movie_indices.append(metadata['movie_idx'])
    movie_names.append(metadata['movie_name'])
    release_years.append(metadata['release_year'])
    ratings.append(metadata['rating'])
    votes.append(metadata['votes'])
    genres.append(metadata['genre'])
    num_utterances.append(len(convo.get_utterance_ids()))

# Create a DataFrame from the lists
data = {
    'Conversation ID': conversation_ids,
    'Movie Index': movie_indices,
    'Movie Name': movie_names,
    'Rating': ratings,
}

df = pd.DataFrame(data)

# %%
df
# Out:
#       Conversation ID Movie Index                  Movie Name Rating
# 0               L1044          m0  10 things i hate about you   6.90
# 1                L984          m0  10 things i hate about you   6.90
# 2                L924          m0  10 things i hate about you   6.90
# 3                L870          m0  10 things i hate about you   6.90
# 4                L866          m0  10 things i hate about you   6.90
# ...               ...         ...                         ...    ...
# 83092         L666324        m616                   zulu dawn   6.40
# 83093         L666262        m616                   zulu dawn   6.40
# 83094         L666520        m616                   zulu dawn   6.40
# 83095         L666369        m616                   zulu dawn   6.40
# 83096         L666256        m616                   zulu dawn   6.40
#
# [83097 rows x 4 columns]

# %%
# Create a Reader object specifying the rating scale
reader = Reader(rating_scale=(1, 10))

# %%
# Load the dataset into Surprise format
data = df[['Conversation ID','Movie Name','Rating']]
data = Dataset.load_from_df(data, reader)

# Split the data into training and testing sets (80% train, 20% test)
trainset, testset = train_test_split(data, test_size=0.2, random_state=42)

# Create and train the SVD recommendation model
model = SVD()
model.fit(trainset)

# Evaluate the model on the testing data (calculate RMSE)
predictions = model.test(testset)
rmse = accuracy.rmse(predictions)
# Out:
# RMSE: 0.0638

# %%
# Generate recommendations for a specific user (e.g., user_id='L236416')
user_id = 'L36547'
user_movies = df[df['Conversation ID'] == user_id]['Movie Name'].unique()

# Create a list of unrated movies for the user
all_movies = df['Movie Name'].unique()
unrated_movies = np.setdiff1d(all_movies, user_movies)

# Generate predictions for unrated movies
user_recommendations = []
for movie_id in unrated_movies:
    predicted_rating = model.predict(user_id, movie_id).est
    user_recommendations.append((movie_id, predicted_rating))

    # Sort recommendations by predicted rating (highest first)
user_recommendations.sort(key=lambda x: x[1], reverse=True)

# %%
# Display the top n recommendations
top_n = 3
print(f'Top {top_n} recommendations for user {user_id}:')
for movie_id, predicted_rating in user_recommendations[:top_n]:
    print(f'Movie ID: {movie_id}, Predicted Rating: {predicted_rating:.2f}')
# Out:
# Top 3 recommendations for user L36547:
# Movie ID: neuromancer, Predicted Rating: 9.12
# Movie ID: the godfather, Predicted Rating: 9.06
# Movie ID: goodfellas, Predicted Rating: 8.87
